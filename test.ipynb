# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

sns.set_style("whitegrid")

# %%
#scatter plot for all lap data for the subsession
lap_data = pd.read_csv("results\\21S3\\3280#VRS_GT_Sprint_Series\\1#Road_Atlanta#Full_Course\\3280_1_lap_data.csv", index_col = 0)
sns.set(rc={'figure.figsize':(12,9)})
sns.scatterplot(data = lap_data, x = 'oldirating', y = 'lap_time', hue = "carid", palette = "rainbow")
# Out:
# <AxesSubplot:xlabel='oldirating', ylabel='lap_time'>

# %%
lap_data.custid
# Out:
# subsessionid
# 39772527    332520.594262
# 39772528    376393.966981
# 39772529    434979.936585
# 39772530    450251.242424
# 39772531    480540.047904
#                 ...
# 39878396    382329.702479
# 39878397    429333.866397
# 39878398    456051.447826
# 39878399    450950.279279
# 39878400    485729.020942
# Name: custid, Length: 668, dtype: float64

# %%
#scatter plot avg of the lap times
lap_data = pd.read_csv("results\\21S3\\3280#VRS_GT_Sprint_Series\\1#Road_Atlanta#Full_Course\\3280_1_lap_data_mmm.csv", index_col = 0)
lap_data = lap_data[lap_data['type'] == 'avg']

sns.set(rc={'figure.figsize':(12,9)})
sns.scatterplot(data = lap_data, x = 'oldirating', y = 'lap_time', hue = "weather_temp_value", palette = "rainbow")
# Out:
# <AxesSubplot:xlabel='oldirating', ylabel='lap_time'>

# %%
#scatter plot min of the lap times
lap_data = pd.read_csv("results\\21S3\\3280#VRS_GT_Sprint_Series\\6#Circuit_de_Spa-Francorchamps#Endurance\\3280_6_lap_data_mmm.csv", index_col = 0)
lap_data = lap_data[lap_data['type'] == 'min']

sns.set(rc={'figure.figsize':(12,9)})
sns.scatterplot(data = lap_data, x = 'oldirating', y = 'lap_time', hue = "weather_temp_value", palette = "rainbow")
# Out:
# <AxesSubplot:xlabel='oldirating', ylabel='lap_time'>

# %%
lap_data = pd.read_csv("results\\21S3\\3280#VRS_GT_Sprint_Series\\6#Circuit_de_Spa-Francorchamps#Endurance\\3280_6_lap_data.csv", index_col = 0)
lap_data['lap_time'] = lap_data['lap_time']/10000
#lap_data = lap_data.groupby('subsessionid').mean()
#lap_data
# Out:
#               weather_temp_value         custid   oldirating       carid  \
# subsessionid
# 39772527               66.476471  332520.594262  4330.270492  125.081967
# 39772528               66.476471  376393.966981  2435.985849  116.547170
# 39772529               66.476471  434979.936585  1893.570732  117.068293
# 39772530               66.476471  450251.242424  1617.974026  117.294372
# 39772531               66.476471  480540.047904  1365.161677  113.568862
# ...                          ...            ...          ...         ...
# 39878396               68.232002  382329.702479  1889.280992  117.462810
# 39878397               68.232002  429333.866397  1677.210526  119.611336
# 39878398               68.232002  456051.447826  1509.856522  112.343478
# 39878399               68.232002  450950.279279  1304.941441  115.229730
# 39878400               68.232002  485729.020942  1033.518325  116.345550
#
#                 lap_time
# subsessionid
# 39772527      137.606096
# ...

# %%
sns.set(rc={'figure.figsize':(12,9)})
sns.scatterplot(data = lap_data, x = 'oldirating', y = 'lap_time', hue = "weather_temp_value", palette = "rainbow")
# Out:
# <AxesSubplot:xlabel='oldirating', ylabel='lap_time'>

# %%
#take the df and try to divide it into buckets of 1k irating? idk
